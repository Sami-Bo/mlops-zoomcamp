# %% [markdown]
# ### Scenario 1: A single data scientist participating in an ML competition
#
# MLflow setup:
#
# - Tracking server: no
# - Backend store: local filesystem
# - Artifacts store: local filesystem
#
# The experiments can be explored locally by launching the MLflow UI

# %%
import mlflow

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'file:///workspaces/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/mlruns'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///workspaces/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/mlruns/0', creation_time=1772714515565, experiment_id='0', last_update_time=1772714515565, lifecycle_stage='active', name='Default', tags={}>]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():
    X,y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state":42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X,y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2026/03/05 12:47:04 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2026/03/05 12:47:04 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/03/05 12:47:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# default artifacts URI: 'file:///workspaces/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/mlruns/790172847412748540/53e80e4229f04bf9a77b1ccb48a057d4/artifacts'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///workspaces/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/mlruns/790172847412748540', creation_time=1772714824427, experiment_id='790172847412748540', last_update_time=1772714824427, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='file:///workspaces/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/mlruns/0', creation_time=1772714515565, experiment_id='0', last_update_time=1772714515565, lifecycle_stage='active', name='Default', tags={}>]

# %% [markdown]
# ### Interacting with the model registry

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()

# %%
from mlflow.exceptions import MlflowException

# ca levait une exception avec list_registered_models xd
try:
    client.search_registered_models()
except MlflowException:
    print("Pas possible d'accéder au registre de modèle en tracking local simple avec mlruns (il faut un backend compatible Model Registry comme une bd SQL) ")
